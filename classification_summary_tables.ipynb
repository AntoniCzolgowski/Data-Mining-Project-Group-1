# %%
import pandas as pd
from IPython.display import display, HTML

# %% [markdown]
# ## Table 2: 5-Class Volatility Bins

# %%
table2 = pd.DataFrame({
    'Quantile Title': ['Highly Stable', 'Stable', 'Moderate', 'Volatile', 'Highly Volatile'],
    'Median Volatility Score': [-1.6745, -0.9542, -0.3144, 0.6071, 2.0760],
    'Count': [50, 50, 50, 50, 50]
})

styled_t2 = table2.style.hide(axis='index').set_caption(
    'Table 2: 5-class target variable quantiles'
).set_table_styles([
    {'selector': 'caption', 'props': [('font-size', '12px'), ('font-style', 'italic'), ('color', '#666')]},
    {'selector': 'th', 'props': [('background-color', '#d4a843'), ('color', 'white'), ('padding', '6px 12px')]},
    {'selector': 'td', 'props': [('padding', '6px 12px'), ('text-align', 'center')]}
])

print('5-class Volatility Bins')
display(styled_t2)
# Out:
# 5-class Volatility Bins
# <style type="text/css">
# #T_86300 caption {
#   font-size: 12px;
#   font-style: italic;
#   color: #666;
# }
# #T_86300 th {
#   background-color: #d4a843;
#   color: white;
#   padding: 6px 12px;
# }
# #T_86300 td {
#   padding: 6px 12px;
#   text-align: center;
# }
# </style>
# <table id="T_86300">
#   <caption>Table 2: 5-class target variable quantiles</caption>
#   <thead>
#     <tr>
#       <th id="T_86300_level0_col0" class="col_heading level0 col0" >Quantile Title</th>
#       <th id="T_86300_level0_col1" class="col_heading level0 col1" >Median Volatility Score</th>
#       <th id="T_86300_level0_col2" class="col_heading level0 col2" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_86300_row0_col0" class="data row0 col0" >Highly Stable</td>
#       <td id="T_86300_row0_col1" class="data row0 col1" >-1.674500</td>
#       <td id="T_86300_row0_col2" class="data row0 col2" >50</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## Table 12: SVM Kernel Comparison

# %%
table12 = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision (macro)', 'Recall (macro)', 'F1-macro', 'ROC-AUC'],
    'Linear': [0.368, 0.365, 0.368, 0.364, 0.765],
    'RBF':    [0.352, 0.346, 0.352, 0.347, 0.790]
})

styled_t12 = table12.style.hide(axis='index').set_caption(
    'Table 12: SVM kernel comparison — Linear vs RBF (5-fold nested CV)'
).set_table_styles([
    {'selector': 'caption', 'props': [('font-size', '12px'), ('font-style', 'italic'), ('color', '#666')]},
    {'selector': 'th', 'props': [('background-color', '#d4a843'), ('color', 'white'), ('padding', '6px 12px')]},
    {'selector': 'td', 'props': [('padding', '6px 12px'), ('text-align', 'center')]}
]).format(precision=3)

print('SVM: Kernel Comparison')
display(styled_t12)
# Out:
# SVM: Kernel Comparison
# <style type="text/css">
# #T_9fb40 caption {
#   font-size: 12px;
#   font-style: italic;
#   color: #666;
# }
# #T_9fb40 th {
#   background-color: #d4a843;
#   color: white;
#   padding: 6px 12px;
# }
# #T_9fb40 td {
#   padding: 6px 12px;
#   text-align: center;
# }
# </style>
# <table id="T_9fb40">
#   <caption>Table 12: SVM kernel comparison — Linear vs RBF (5-fold nested CV)</caption>
#   <thead>
#     <tr>
#       <th id="T_9fb40_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_9fb40_level0_col1" class="col_heading level0 col1" >Linear</th>
#       <th id="T_9fb40_level0_col2" class="col_heading level0 col2" >RBF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9fb40_row0_col0" class="data row0 col0" >Accuracy</td>
#       <td id="T_9fb40_row0_col1" class="data row0 col1" >0.368</td>
#       <td id="T_9fb40_row0_col2" class="data row0 col2" >0.352</td>
#     </tr>
#     <tr>
# ...
